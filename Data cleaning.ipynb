# %%
import pandas as pd
import numpy as np
from scipy import stats

# Excelデータ読み込み
df = pd.read_excel('【元データ】LightGBM分析データ_欠損値処理.xlsx')

# 空の文字列をNaNに置き換え
df = df.replace('', np.nan)

# 数値型に変換するための関数を定義
def convert_to_numeric(value):
    try:
        return float(value)
    except:
        return np.nan

# 数値型に変換
cat_cols = ['FBS', 'HbA1c', 'US', 'HbA1c_NGSP']
for col in cat_cols:
    df[col] = df[col].apply(convert_to_numeric)

# 平均を計算
mean_values = df.mean(skipna=True)
std_dev = df.std(skipna=True, ddof=1)  # 不偏標準偏差を計算するためにddof=1を指定

# データの個数
n = len(df)

# 95%信頼区間を計算
confidence_interval_lower = mean_values - 1.96 * std_dev / np.sqrt(n)
confidence_interval_upper = mean_values + 1.96 * std_dev / np.sqrt(n)
confidence_interval = confidence_interval_upper - mean_values

# 平均、95%信頼区間を出力
result_df = pd.DataFrame({'平均値': mean_values, '95%信頼区間_下限': confidence_interval_lower, '95%信頼区間_上限': confidence_interval_upper, '95%Cl': confidence_interval})
print(result_df)
# Out:
#                                              平均値  95%信頼区間_下限  95%信頼区間_上限  \
# Age                                    57.061704   56.818273   57.305135
# T2db                                    0.053991    0.049202    0.058780
# sex                                     1.476803    1.466219    1.487386
# weight                                 62.567208   62.283270   62.851146
# BMI                                    23.725476   23.641492   23.809461
# SBP                                   128.630244  128.250328  129.010161
# DBP                                    76.688325   76.433925   76.942726
# Time of blood collection _after meal    2.081668    2.074027    2.089309
# TG                                    116.231273  114.374710  118.087835
# HDL                                    64.019177   63.650995   64.387359
# LDL                                   121.590277  120.922987  122.257566
# GOT                                    24.074091   23.815133   24.333050
# GPT                                    24.397686   23.985953   24.809419
# γ_GT                                   40.737525   39.670019   41.805030
# FBS                                    92.011275   91.316922   92.705629
# HbA1c                                   5.351184    5.337829    5.364540
# US                                      1.138967    1.124303    1.153631
# Ht                                     42.818849   42.738494   42.899205
# Hb                                     14.157907   14.129087   14.186727
# RBC                                   463.529055  462.578360  464.479749
# metabolic syndrome                      2.516423    2.499703    2.533143
# Health Guidance Level                   2.799368    2.787905    2.810831
# HbA1c_NGSP                              5.735685    5.722174    5.749195
# Medication1_Blood Pressure              1.710640    1.701032    1.720249
# Medication2_Blood Sugar                 1.912677    1.906695    1.918659
# Medication3_TG                          1.775840    1.767003    1.784676
# anaemia                                 1.897697    1.891275    1.904118
# smoking                                 1.731359    1.721967    1.740751
# Weight change                           1.597660    1.587269    1.608051
# Exercise habit                          1.727049    1.717610    1.736488
# physical activity                       1.576738    1.566269    1.587208
# walking speed                           1.513737    1.503146    1.524327
# One-year weight change                  1.680000    1.669912    1.690088
# Eating style1_quickly                   1.738927    1.726742    1.751113
# Eating style2_Before bedtime            1.755506    1.746399    1.764613
# Eating style3_midnight snack            1.840000    1.832072    1.847928
# eating habits                           1.815138    1.806913    1.823364
# drinking                                2.174539    2.157102    2.191976
# amount of drinking                      1.684406    1.666101    1.702711
# Sleeping                                1.304084    1.294337    1.313832
# Lifestyle Improvements                  2.601751    2.571546    2.631956
# Health Guidance Preference              1.627295    1.617050    1.637541
# chewing                                 1.192617    1.183664    1.201571
# Eating style4_meal_snacking             1.999752    1.986341    2.013164
#
#                                          95%Cl
# Age                                   0.243431
# T2db                                  0.004789
# sex                                   0.010583
# weight                                0.283938
# BMI                                   0.083985
# SBP                                   0.379916
# DBP                                   0.254400
# Time of blood collection _after meal  0.007641
# TG                                    1.856562
# HDL                                   0.368182
# LDL                                   0.667289
# GOT                                   0.258959
# GPT                                   0.411733
# γ_GT                                  1.067505
# FBS                                   0.694354
# HbA1c                                 0.013356
# US                                    0.014664
# Ht                                    0.080356
# Hb                                    0.028820
# RBC                                   0.950694
# metabolic syndrome                    0.016720
# Health Guidance Level                 0.011463
# HbA1c_NGSP                            0.013511
# Medication1_Blood Pressure            0.009609
# Medication2_Blood Sugar               0.005982
# Medication3_TG                        0.008837
# anaemia                               0.006421
# smoking                               0.009392
# Weight change                         0.010391
# Exercise habit                        0.009439
# physical activity                     0.010469
# walking speed                         0.010591
# One-year weight change                0.010088
# Eating style1_quickly                 0.012186
# Eating style2_Before bedtime          0.009107
# Eating style3_midnight snack          0.007928
# eating habits                         0.008225
# drinking                              0.017437
# amount of drinking                    0.018305
# Sleeping                              0.009748
# Lifestyle Improvements                0.030205
# Health Guidance Preference            0.010246
# chewing                               0.008954
# Eating style4_meal_snacking           0.013411

# %% [markdown]
# ## 空白セルをNAに置き換え

# %%
import pandas as pd

# Excelデータ読み込み
df = pd.read_excel('補完データ_test02.xlsx')

# 空白セルをNaNに置き換え
df.replace('', pd.NA, inplace=True)

# -1をNaNに置き換え
df.replace(-1, pd.NA, inplace=True)

# 結果を表示
print(df)

# データを保存
df.to_excel('補完データ_test02_na.xlsx', sheet_name='fill_na')
# Out:
#             x1  x2  x3        x4        x5        x6        x7  x8        x9  \
# 0     0.255765   1   2 -1.206514 -1.242709  1.749620  0.858879   2 -0.584718
# 1     1.039173   1   1  0.345732  0.397256  0.411042  0.109252   2  0.271280
# 2     1.387354   1   2 -0.572183 -0.611953 -0.815989 -1.140127   2 -0.356452
# 3     0.603946   1   1 -0.139345 -0.384881  1.136105  0.192544   2 -0.322212
# 4     1.474399   1   1  0.181553  0.044033 -0.035151  0.609003   4  1.857728
# ...        ...  ..  ..       ...       ...       ...       ...  ..       ...
# 8552 -0.179462   0   1  0.614390 -0.359651 -1.764149 -1.390003   2 -0.676024
# 8553  0.690992   0   2 -0.855766 -0.687644 -0.871763 -0.223916   2 -0.173839
# 8554  0.255765   0   2 -1.646815 -1.495012 -1.931471 -1.639878   2 -0.847224
# 8555 -0.179462   0   2 -0.654272 -0.208270 -0.314022  0.359128   2 -0.927117
# 8556  0.690992   0   2 -1.318455 -0.611953 -0.090925  0.109252   2 -0.698851
#
#            x10  ...  x35  x36  x37  x38  x39 x40  x41  x42  x43  x44
# 0     0.401758  ...    2    2    2    3    1   1    1    2    1    1
# 1    -0.116207  ...    2    2    2    3    1   1    1    2    1    2
# 2     0.574413  ...    2    2    2    2    1   2    4    1    1    2
# 3    -0.346414  ...    2    2    2    1    4   2    1    1    1    1
# 4    -0.749276  ...    2    2    2    3    1   1    3    1    1    1
# ...        ...  ...  ...  ...  ...  ...  ...  ..  ...  ...  ...  ...
# 8552 -0.461517  ...    2    2    2    3    1   1    3    2    1    1
# 8553  2.358516  ...    2    2    2    3    1   2    1    1    1    1
# 8554  1.437689  ...    2    2    2    3    1   2    5    2    2    2
# 8555  0.171551  ...    2    2    2    3    4   1    2    2    2    2
# 8556  1.782999  ...    2    2    2    1    1   2    1    1    1    3
#
# [8557 rows x 44 columns]

# %%
import pandas as pd

# Excelデータ読み込み
df = pd.read_excel('補完データ_test02.xlsx')

# 欠損値の数を検索
missing_values_count = df.isnull().sum()

# 欠損値の数を表示
print(missing_values_count)
# Out:
# x1        0
# x2        0
# x3        0
# x4        0
# x5        0
# x6        0
# x7        0
# x8        0
# x9        0
# x10       0
# x11       0
# x12       0
# x13       0
# x14       0
# x15       0
# x16    3020
# x17       0
# x18       0
# x19       0
# x20       0
# x21       0
# x22       0
# x23    3020
# x24       0
# x25       0
# x26       0
# x27       0
# x28       0
# x29       0
# x30       0
# x31       0
# x32       0
# x33       0
# x34       0
# x35       0
# x36       0
# x37       0
# x38       0
# x39       0
# x40       0
# x41       0
# x42       0
# x43       0
# x44       0
# dtype: int64

# %% [markdown]
# ## データ標準化

# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.preprocessing import StandardScaler

# ファイルの読み込み（'your_file.xlsx'は読み込むExcelファイル名に置き換えてください）
df = pd.read_excel('補完データ_test07.xlsx')

# 空の文字列をNaNに置き換え
df = df.replace('', np.nan)

# 数値型に変換するための関数を定義
def convert_to_numeric(value):
    try:
        return float(value)
    except:
        return np.nan

# 数値型に変換
cat_cols = ['FBS', 'HbA1c', 'US', 'HbA1c_NGSP']
for col in cat_cols:
    df[col] = df[col].apply(convert_to_numeric)

# 数値型の列のみを抽出
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# 標準化を行いたい列名のリスト（'column1', 'column2'...は実際の列名に置き換えてください）
columns_to_standardize = ['Age',
                          'weight',
                          'BMI',
                          'SBP',
                          'DBP',
                          'TG',
                          'HDL',
                          'LDL',
                          'GOT',
                          'GPT',
                          'γ_GT',
                          'FBS',
                          'HbA1c',
                          'Ht',
                          'Hb',
                          'RBC',
                          'HbA1c_NGSP']

# 標準化を行いたい列のうち、数値型の列のみを抽出
columns_to_standardize = list(set(columns_to_standardize) & set(numeric_columns))

scaler = StandardScaler()

# 各列を標準化
for column in columns_to_standardize:
    df[column] = scaler.fit_transform(df[[column]])

# 標準化されたデータを新しいExcelファイルとして保存（'new_file.xlsx'は新しいファイル名に置き換えてください）
df.to_excel('lightGBM_data_standard04.xlsx', index=False)

# %% [markdown]
# ## 欠損値確認

# %%
import pandas as pd

# Excelファイルを読み込む
df = pd.read_excel('【元データ】LightGBM分析データ_欠損値処理.xlsx')

# -1の値をNaNに変換
# df = df.replace(-1, pd.NA)


df.isnull().sum()
# 変換後のデータフレームを表示
# print(df)

#新しいファイルにダウンロード
# df.to_excel('kokuho_data_null.xlsx')
# Out:
# Age                                        0
# T2db                                       0
# sex                                        0
# weight                                     0
# BMI                                        4
# SBP                                        0
# DBP                                        0
# Time of blood collection _after meal    5104
# TG                                         0
# HDL                                        0
# LDL                                        0
# GOT                                        0
# GPT                                        0
# γ_GT                                       0
# FBS                                        0
# HbA1c                                   3020
# US                                         0
# Ht                                      5098
# Hb                                      5098
# RBC                                     5098
# metabolic syndrome                         2
# Health Guidance Level                     14
# HbA1c_NGSP                              3020
# Medication1_Blood Pressure                14
# Medication2_Blood Sugar                   14
# Medication3_TG                            14
# anaemia                                  395
# smoking                                   14
# Weight change                            437
# Exercise habit                           431
# physical activity                        432
# walking speed                            440
# One-year weight change                  8532
# Eating style1_quickly                    429
# Eating style2_Before bedtime             430
# Eating style3_midnight snack            8532
# eating habits                            432
# drinking                                 427
# amount of drinking                      2375
# Sleeping                                 477
# Lifestyle Improvements                   449
# Health Guidance Preference               497
# chewing                                  484
# Eating style4_meal_snacking              479
# dtype: int64

# %%
df.describe()
# Out:
#                Age         T2db          sex       weight          BMI  \
# count  8557.000000  8557.000000  8557.000000  8557.000000  8553.000000
# mean     57.061704     0.053991     1.476803    62.567208    23.725476
# std      11.488939     0.226013     0.499491    13.400718     3.963730
# min      35.000000     0.000000     1.000000    27.900000    13.700000
# 25%      46.000000     0.000000     1.000000    52.700000    21.000000
# 50%      60.000000     0.000000     1.000000    61.100000    23.300000
# 75%      68.000000     0.000000     2.000000    70.400000    25.900000
# max      74.000000     1.000000     2.000000   128.400000    55.400000
#
#                SBP          DBP  Time of blood collection _after meal  \
# count  8557.000000  8557.000000                           3453.000000
# mean    128.630244    76.688325                              2.081668
# std      17.930513    12.006669                              0.360639
# min      78.000000    39.000000                              2.000000
# 25%     116.000000    68.000000                              2.000000
# 50%     128.000000    76.000000                              2.000000
# 75%     139.000000    84.000000                              2.000000
# max     205.000000   150.000000                              4.000000
#
#                 TG          HDL  ...  Eating style2_Before bedtime  \
# count  8557.000000  8557.000000  ...                   8127.000000
# mean    116.231273    64.019177  ...                      1.755506
# std      87.622215    17.376693  ...                      0.429813
# min       0.000000     0.000000  ...                      1.000000
# 25%      67.000000    51.000000  ...                      2.000000
# 50%      94.000000    62.000000  ...                      2.000000
# 75%     137.000000    74.000000  ...                      2.000000
# max    2153.000000   197.000000  ...                      2.000000
#
#        Eating style3_midnight snack  eating habits    drinking   \
# count                     25.000000    8125.000000  8130.000000
# mean                       1.840000       1.815138     2.174539
# std                        0.374166       0.388209     0.822949
# min                        1.000000       1.000000     1.000000
# 25%                        2.000000       2.000000     1.000000
# 50%                        2.000000       2.000000     2.000000
# 75%                        2.000000       2.000000     3.000000
# max                        2.000000       2.000000     3.000000
#
#        amount of drinking     Sleeping  Lifestyle Improvements  \
# count         6182.000000  8080.000000             8108.000000
# mean             1.684406     1.304084                2.601751
# std              0.863924     0.460047                1.425553
# min              1.000000     1.000000                1.000000
# 25%              1.000000     1.000000                1.000000
# 50%              1.000000     1.000000                2.000000
# 75%              2.000000     2.000000                4.000000
# max              4.000000     2.000000                5.000000
#
#        Health Guidance Preference      chewing  Eating style4_meal_snacking
# count                 8060.000000  8073.000000                  8078.000000
# mean                     1.627295     1.192617                     1.999752
# std                      0.483554     0.422585                     0.632964
# min                      1.000000     1.000000                     1.000000
# 25%                      1.000000     1.000000                     2.000000
# 50%                      2.000000     1.000000                     2.000000
# 75%                      2.000000     1.000000                     2.000000
# max                      2.000000     3.000000                     3.000000
#
# [8 rows x 44 columns]

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Excelデータ読み込み
df = pd.read_excel('【元データ】LightGBM分析データ_欠損値処理.xlsx')

# 空の文字列をNaNに置き換え
df = df.replace('', np.nan)

# 数値型に変換するための関数を定義
def convert_to_numeric(value):
    try:
        return float(value)
    except:
        return np.nan

# 数値型に変換
cat_cols = ['FBS', 'HbA1c', 'US', 'HbA1c_NGSP']
for col in cat_cols:
    df[col] = df[col].apply(convert_to_numeric)

# T2DB列が1の行のみを抽出
df_t2db_0 = df[df['T2db'] == 0]

# 平均を計算
mean_values = df_t2db_0.mean(skipna=True)
std_dev = df_t2db_0.std(skipna=True, ddof=1)  # 不偏標準偏差を計算するためにddof=1を指定

# データの個数
n = len(df_t2db_0)

# 95%信頼区間を計算
confidence_interval_lower = mean_values - 1.96 * std_dev / np.sqrt(n)
confidence_interval_upper = mean_values + 1.96 * std_dev / np.sqrt(n)
confidence_interval = confidence_interval_upper - mean_values

# 平均、95%信頼区間を出力
result_df = pd.DataFrame({'平均値': mean_values, '95%信頼区間_下限': confidence_interval_lower, '95%信頼区間_上限': confidence_interval_upper, '95%Cl': confidence_interval})
print(result_df)
# Out:
#                                              平均値  95%信頼区間_下限  95%信頼区間_上限  \
# Age                                    56.538233   56.288690   56.787777
# T2db                                    0.000000    0.000000    0.000000
# sex                                     1.482520    1.471634    1.493406
# weight                                 62.524027   62.231599   62.816456
# BMI                                    23.684773   23.598491   23.771056
# SBP                                   128.329833  127.939404  128.720262
# DBP                                    76.661643   76.399096   76.924190
# Time of blood collection _after meal    2.080656    2.072883    2.088428
# TG                                    115.698826  113.781018  117.616635
# HDL                                    64.244237   63.865130   64.623344
# LDL                                   122.130080  121.443919  122.816242
# GOT                                    24.010871   23.742746   24.278996
# GPT                                    24.329957   23.903418   24.756496
# γ_GT                                   40.731069   39.628354   41.833783
# FBS                                    90.778157   90.078770   91.477545
# HbA1c                                   5.301821    5.289409    5.314233
# US                                      1.116383    1.102501    1.130264
# Ht                                     42.778193   42.697057   42.859328
# Hb                                     14.140144   14.110949   14.169339
# RBC                                   463.032089  462.073285  463.990893
# metabolic syndrome                      2.534783    2.517908    2.551658
# Health Guidance Level                   2.793700    2.781760    2.805640
# HbA1c_NGSP                              5.686430    5.673798    5.699062
# Medication1_Blood Pressure              1.724521    1.714788    1.734254
# Medication2_Blood Sugar                 1.931563    1.926062    1.937064
# Medication3_TG                          1.788882    1.779991    1.797773
# anaemia                                 1.896257    1.889614    1.902900
# smoking                                 1.727363    1.717661    1.737064
# Weight change                           1.600677    1.590007    1.611347
# Exercise habit                          1.733091    1.723454    1.742727
# physical activity                       1.579420    1.568665    1.590174
# walking speed                           1.514781    1.503892    1.525669
# One-year weight change                       NaN         NaN         NaN
# Eating style1_quickly                   1.740832    1.728325    1.753339
# Eating style2_Before bedtime            1.751593    1.742180    1.761007
# Eating style3_midnight snack                 NaN         NaN         NaN
# eating habits                           1.809158    1.800597    1.817719
# drinking                                2.167880    2.149951    2.185809
# amount of drinking                      1.686860    1.668063    1.705657
# Sleeping                                1.306595    1.296550    1.316640
# Lifestyle Improvements                  2.581877    2.551057    2.612698
# Health Guidance Preference              1.631082    1.620570    1.641594
# chewing                                 1.189637    1.180501    1.198773
# Eating style4_meal_snacking             1.996348    1.982518    2.010178
#
#                                          95%Cl
# Age                                   0.249544
# T2db                                  0.000000
# sex                                   0.010886
# weight                                0.292428
# BMI                                   0.086283
# SBP                                   0.390429
# DBP                                   0.262547
# Time of blood collection _after meal  0.007773
# TG                                    1.917809
# HDL                                   0.379107
# LDL                                   0.686161
# GOT                                   0.268125
# GPT                                   0.426539
# γ_GT                                  1.102714
# FBS                                   0.699388
# HbA1c                                 0.012412
# US                                    0.013882
# Ht                                    0.081135
# Hb                                    0.029195
# RBC                                   0.958804
# metabolic syndrome                    0.016875
# Health Guidance Level                 0.011940
# HbA1c_NGSP                            0.012632
# Medication1_Blood Pressure            0.009733
# Medication2_Blood Sugar               0.005501
# Medication3_TG                        0.008891
# anaemia                               0.006643
# smoking                               0.009702
# Weight change                         0.010670
# Exercise habit                        0.009637
# physical activity                     0.010755
# walking speed                         0.010888
# One-year weight change                     NaN
# Eating style1_quickly                 0.012507
# Eating style2_Before bedtime          0.009413
# Eating style3_midnight snack               NaN
# eating habits                         0.008561
# drinking                              0.017929
# amount of drinking                    0.018797
# Sleeping                              0.010045
# Lifestyle Improvements                0.030820
# Health Guidance Preference            0.010512
# chewing                               0.009136
# Eating style4_meal_snacking           0.013830

# %%
df_meanSD = df_t2db_0.describe()

# %%
df_meanSD.to_excel('t2db_0.xlsx', index=False)

# %% [markdown]
# ## 各項目の頻度を計算

# %%
import pandas as pd
import numpy as np

# Excelデータ読み込み
df = pd.read_excel('【元データ】LightGBM分析データ_欠損値処理.xlsx')

# 数値型に変換するための関数を定義
def convert_to_numeric(value):
    try:
        return float(value)
    except:
        return np.nan

# 数値型に変換
cat_cols = ['FBS', 'HbA1c', 'US', 'HbA1c_NGSP']
for col in cat_cols:
    df[col] = df[col].apply(convert_to_numeric)
    
df = df.drop(['Age',
              'weight',
              'BMI',
              'SBP',
              'DBP',
              'TG',
              'HDL',
              'LDL',
              'GOT',
              'GPT',
              'γ_GT',
              'FBS',
              'HbA1c',
              'Ht',
              'Hb',
              'RBC',
              'HbA1c_NGSP'], axis=1)

# T2DB列が0か1の行のみを抽出
df_t2db_1 = df[df['T2db'] == 0]

# 各列の項目ごとの頻度を計算
frequency_df = df_t2db_1.apply(pd.Series.value_counts)

# 各列の項目ごとの割合を計算
percentage_df = df_t2db_1.apply(lambda x: x.value_counts(normalize=True))

# 結果を表示
print("頻度:")
print(frequency_df)
frequency_df.to_excel('frequency_df_0.xlsx', index=False)

print("\n割合:")
print(percentage_df)
percentage_df.to_excel('percentage_df_0.xlsx', index=False)
# Out:
# 頻度:
#        T2db     sex  Time of blood collection _after meal    US  \
# 0.0  8095.0     NaN                                   NaN    49
# 1.0     NaN  4189.0                                   NaN  7705
# 2.0     NaN  3906.0                                2885.0    63
# 3.0     NaN     NaN                                  84.0    56
# 4.0     NaN     NaN                                  81.0    68
# 5.0     NaN     NaN                                   NaN   153
#
#      metabolic syndrome  Health Guidance Level  Medication1_Blood Pressure  \
# 0.0                 NaN                    NaN                         NaN
# 1.0              1400.0                  545.0                      2230.0
# 2.0               986.0                  588.0                      5865.0
# 3.0              5686.0                 6954.0                         NaN
# 4.0                21.0                    8.0                         NaN
# 5.0                 NaN                    NaN                         NaN
#
#      Medication2_Blood Sugar  Medication3_TG  anaemia  ...  \
# 0.0                      NaN             NaN      NaN  ...
# 1.0                    554.0          1709.0    801.0  ...
# 2.0                   7541.0          6386.0   6920.0  ...
# 3.0                      NaN             NaN      NaN  ...
# 4.0                      NaN             NaN      NaN  ...
# 5.0                      NaN             NaN      NaN  ...
#
#      Eating style2_Before bedtime  Eating style3_midnight snack  \
# 0.0                           NaN                           NaN
# 1.0                        1910.0                           NaN
# 2.0                        5779.0                           NaN
# 3.0                           NaN                           NaN
# 4.0                           NaN                           NaN
# 5.0                           NaN                           NaN
#
#      eating habits  drinking   amount of drinking  Sleeping  \
# 0.0            NaN        NaN                 NaN       NaN
# 1.0         1467.0     2067.0              3124.0    5299.0
# 2.0         6220.0     2265.0              1709.0    2343.0
# 3.0            NaN     3358.0               765.0       NaN
# 4.0            NaN        NaN               262.0       NaN
# 5.0            NaN        NaN                 NaN       NaN
#
#      Lifestyle Improvements  Health Guidance Preference  chewing  \
# 0.0                     NaN                         NaN      NaN
# 1.0                  2143.0                      2813.0   6294.0
# 2.0                  2256.0                      4812.0   1283.0
# 3.0                  1200.0                         NaN     85.0
# 4.0                   807.0                         NaN      NaN
# 5.0                  1264.0                         NaN      NaN
#
#      Eating style4_meal_snacking
# 0.0                          NaN
# 1.0                       1559.0
# 2.0                       4577.0
# 3.0                       1531.0
# 4.0                          NaN
# 5.0                          NaN
#
# [6 rows x 27 columns]
#
# 割合:
#      T2db      sex  Time of blood collection _after meal        US  \
# 0.0   1.0      NaN                                   NaN  0.006054
# 1.0   NaN  0.51748                                   NaN  0.951940
# 2.0   NaN  0.48252                              0.945902  0.007784
# 3.0   NaN      NaN                              0.027541  0.006919
# 4.0   NaN      NaN                              0.026557  0.008401
# 5.0   NaN      NaN                                   NaN  0.018903
#
#      metabolic syndrome  Health Guidance Level  Medication1_Blood Pressure  \
# 0.0                 NaN                    NaN                         NaN
# 1.0            0.172989               0.067326                    0.275479
# 2.0            0.121834               0.072637                    0.724521
# 3.0            0.702582               0.859049                         NaN
# 4.0            0.002595               0.000988                         NaN
# 5.0                 NaN                    NaN                         NaN
#
#      Medication2_Blood Sugar  Medication3_TG   anaemia  ...  \
# 0.0                      NaN             NaN       NaN  ...
# 1.0                 0.068437        0.211118  0.103743  ...
# 2.0                 0.931563        0.788882  0.896257  ...
# 3.0                      NaN             NaN       NaN  ...
# 4.0                      NaN             NaN       NaN  ...
# 5.0                      NaN             NaN       NaN  ...
#
#      Eating style2_Before bedtime  Eating style3_midnight snack  \
# 0.0                           NaN                           NaN
# 1.0                      0.248407                           NaN
# 2.0                      0.751593                           NaN
# 3.0                           NaN                           NaN
# 4.0                           NaN                           NaN
# 5.0                           NaN                           NaN
#
#      eating habits  drinking   amount of drinking  Sleeping  \
# 0.0            NaN        NaN                 NaN       NaN
# 1.0       0.190842   0.268791            0.533106  0.693405
# 2.0       0.809158   0.294538            0.291638  0.306595
# 3.0            NaN   0.436671            0.130546       NaN
# 4.0            NaN        NaN            0.044710       NaN
# 5.0            NaN        NaN                 NaN       NaN
#
#      Lifestyle Improvements  Health Guidance Preference   chewing  \
# 0.0                     NaN                         NaN       NaN
# 1.0                0.279400                    0.368918  0.821457
# 2.0                0.294133                    0.631082  0.167450
# 3.0                0.156454                         NaN  0.011094
# 4.0                0.105215                         NaN       NaN
# 5.0                0.164798                         NaN       NaN
#
#      Eating style4_meal_snacking
# 0.0                          NaN
# 1.0                     0.203339
# 2.0                     0.596974
# 3.0                     0.199687
# 4.0                          NaN
# 5.0                          NaN
#
# [6 rows x 27 columns]
